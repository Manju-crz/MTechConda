# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('sl_data.csv')

# %%
data.head(3)
# Out:
#    Patient_ID Skin_treatment         F1         F2          F3           F4  \
# 0           1              N  10.729641  10.099752  125.903083   457.940042
# 1           2              N   9.447797  17.314982   92.407802   557.593030
# 2           3              Y   5.959793  11.681181   61.210054  1223.331231
#
#          F5        F6        F7        F8  ...        F21        F22  \
# 0  0.063236  0.023311  0.176994  0.016436  ...  17.739020  26.182043
# 1  0.109878  0.158177  0.072635  0.002340  ...  14.791384  25.337883
# 2  0.134512  0.025881  0.145682  0.065860  ...  24.200978  33.397013
#
#           F23          F24       F25       F26       F27       F28       F29  \
# 0   92.652045   642.495423  0.181766  0.267158  0.065338  0.003512  0.277782
# 1   78.690352   335.516677  0.140064  0.071308  0.038919  0.084125  0.305742
# 2  208.721687  1994.281664  0.204021  0.204351  0.041159  0.220559  0.181232
#
#         F30
# 0  0.078103
# 1  0.066928
# 2  0.059967
#
# [3 rows x 32 columns]

# %%
data.shape
# Out:
# (1008, 32)

# %%
data.describe()
# Out:
#         Patient_ID           F1           F2           F3           F4  \
# count  1008.000000  1007.000000  1007.000000  1006.000000  1008.000000
# mean    504.419643    12.559906    14.570835   100.306961   752.996970
# std     290.992029     3.886917     4.148864    28.998768   380.141070
# min       1.000000     5.753360     6.407277    38.728787    93.157800
# 25%     252.750000     9.778168    11.453264    80.076676   501.263509
# 50%     504.500000    11.906741    14.019957    96.948771   656.942181
# 75%     756.250000    14.673804    17.077883   113.847418   931.436517
# max     999.000000    34.766907    30.856862   225.169931  3174.048902
#
#                 F5           F6           F7           F8           F9  ...  \
# count  1006.000000  1008.000000  1007.000000  1007.000000  1007.000000  ...
# mean      0.099885     0.077377     0.050885     0.033116     0.227398  ...
# std       0.020030     0.042208     0.057187     0.035179     0.041402  ...
# min       0.050752     0.000202     0.000049     0.000019     0.109000  ...
# 25%       0.085531     0.046498     0.013438     0.007599     0.200184  ...
# 50%       0.099214     0.072006     0.028263     0.018810     0.222983  ...
# 75%       0.113390     0.102346     0.066840     0.050331     0.245806  ...
# max       0.197330     0.260403     0.403034     0.203582     0.341423  ...
#
#                F21          F22          F23          F24          F25  \
# count  1008.000000  1008.000000  1008.000000  1008.000000  1008.000000
# mean     16.972966    25.936423   125.897018   551.940076     0.152804
# std       6.264067     6.674752    48.061970   458.210733     0.033373
# min       6.691088     8.792066    37.237149     1.886849     0.077512
# 25%      12.572423    21.282321    90.948109   246.335394     0.129968
# 50%      15.376920    25.590731   113.419386   438.013333     0.150353
# 75%      19.798613    30.310183   158.802966   709.614695     0.176374
# max      36.658121    56.298122   311.546561  3054.569160     0.240933
#
#                F26          F27          F28          F29          F30
# count  1008.000000  1008.000000  1008.000000  1008.000000  1008.000000
# mean      0.276515     0.184987     0.089401     0.263358     0.074210
# std       0.194750     0.160285     0.064984     0.069820     0.019388
# min       0.000165     0.000333     0.000186     0.075547     0.026947
# 25%       0.142274     0.059360     0.034905     0.212662     0.060734
# 50%       0.233158     0.140857     0.081404     0.255371     0.071194
# 75%       0.369083     0.272310     0.125346     0.304564     0.083195
# max       1.198900     0.934504     0.318810     0.611810     0.166937
#
# [8 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      1008 non-null   int64
#  1   Skin_treatment  1008 non-null   object
#  2   F1              1007 non-null   float64
#  3   F2              1007 non-null   float64
#  4   F3              1006 non-null   float64
#  5   F4              1008 non-null   float64
#  6   F5              1006 non-null   float64
#  7   F6              1008 non-null   float64
#  8   F7              1007 non-null   float64
#  9   F8              1007 non-null   float64
#  10  F9              1007 non-null   float64
#  11  F10             1007 non-null   float64
#  12  F11             1003 non-null   float64
#  13  F12             1008 non-null   float64
#  14  F13             1008 non-null   float64
#  15  F14             1008 non-null   float64
#  16  F15             1008 non-null   float64
#  17  F16             1008 non-null   float64
#  18  F17             1008 non-null   float64
#  19  F18             1008 non-null   float64
#  20  F19             1008 non-null   float64
#  21  F20             1008 non-null   float64
#  22  F21             1008 non-null   float64
#  23  F22             1008 non-null   float64
#  24  F23             1008 non-null   float64
#  25  F24             1008 non-null   float64
#  26  F25             1008 non-null   float64
#  27  F26             1008 non-null   float64
#  28  F27             1008 non-null   float64
#  29  F28             1008 non-null   float64
#  30  F29             1008 non-null   float64
#  31  F30             1008 non-null   float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 252.1+ KB

# %%
# As our dataset is balanced (around 60-40 ratio), there is no need to balance our data
data.Skin_treatment.value_counts(normalize = True)
# Out:
# Skin_treatment
# N    0.632937
# Y    0.367063
# Name: proportion, dtype: float64

# %%
#visualize the count
sns.countplot(data.Skin_treatment,label="count")
plt.show()

# %%
data.columns
# Out:
# Index(['Patient_ID', 'Skin_treatment', 'F1', 'F2', 'F3', 'F4', 'F5', 'F6',
#        'F7', 'F8', 'F9', 'F10', 'F11', 'F12', 'F13', 'F14', 'F15', 'F16',
#        'F17', 'F18', 'F19', 'F20', 'F21', 'F22', 'F23', 'F24', 'F25', 'F26',
#        'F27', 'F28', 'F29', 'F30'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Patient_ID        0
# Skin_treatment    0
# F1                1
# F2                1
# F3                2
# F4                0
# F5                2
# F6                0
# F7                1
# F8                1
# F9                1
# F10               1
# F11               5
# F12               0
# F13               0
# F14               0
# F15               0
# F16               0
# F17               0
# F18               0
# F19               0
# F20               0
# F21               0
# F22               0
# F23               0
# F24               0
# F25               0
# F26               0
# F27               0
# F28               0
# F29               0
# F30               0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Patient_ID        0
# Skin_treatment    0
# F1                0
# F2                0
# F3                0
# F4                0
# F5                0
# F6                0
# F7                0
# F8                0
# F9                0
# F10               0
# F11               0
# F12               0
# F13               0
# F14               0
# F15               0
# F16               0
# F17               0
# F18               0
# F19               0
# F20               0
# F21               0
# F22               0
# F23               0
# F24               0
# F25               0
# F26               0
# F27               0
# F28               0
# F29               0
# F30               0
# dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.boxplot(data['F3'])
plt.title('Boxplot of F3')
plt.ylabel('F3')
plt.show()

# %%
numerical_cols = data.select_dtypes(include=['number']).columns.tolist()
print(numerical_cols)
# Out:
# ['Patient_ID', 'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17', 'F18', 'F19', 'F20', 'F21', 'F22', 'F23', 'F24', 'F25', 'F26', 'F27', 'F28', 'F29', 'F30']

# %%
for column in numerical_cols:
    plt.figure(figsize=(8,5))
    plt.boxplot(data[column])
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
    plt.show()

# %%
fig, (a, b) = plt.subplots(1, 2, figsize=(20, 6))

sns.boxplot(y='F2', x='Skin_treatment', data=data, ax=a)
a.set_title('Boxplot of F2 by Skin Treatment')

sns.boxplot(y='F3', x='Skin_treatment', data=data, ax=b)
b.set_title('Boxplot of F3 by Skin Treatment')

plt.tight_layout()
plt.show()

# %%
corr = data.corr(numeric_only=True)
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
'test'

# %%
sns.pairplot(data[numerical_cols])  # Use selected numerical columns
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sns.pairplot(data[numerical_cols])  # Use selected numerical columns
#       2 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2163, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2161 if kind == "scatter":
#    2162     from .relational import scatterplot  # Avoid circular import
# -> 2163     plotter(scatterplot, **plot_kws)
#    2164 elif kind == "reg":
#    2165     from .regression import regplot  # Avoid circular import
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1425, in PairGrid.map_offdiag(self, func, **kwargs)
#    1414 """Plot with a bivariate function on the off-diagonal subplots.
#    1415
#    1416 Parameters
#    (...)
#    1422
#    1423 """
#    1424 if self.square_grid:
# -> 1425     self.map_lower(func, **kwargs)
#    1426     if not self._corner:
#    1427         self.map_upper(func, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1395, in PairGrid.map_lower(self, func, **kwargs)
#    1384 """Plot with a bivariate function on the lower diagonal subplots.
#    1385
#    1386 Parameters
#    (...)
#    1392
#    1393 """
#    1394 indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1395 self._map_bivariate(func, indices, **kwargs)
#    1396 return self
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1574, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1572     if ax is None:  # i.e. we are in corner mode
#    1573         continue
# -> 1574     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1575 self._add_axis_labels()
#    1577 if "hue" in signature(func).parameters:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1615, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1611 if "hue" not in kwargs:
#    1612     kwargs.update({
#    1613         "hue": hue, "hue_order": self._hue_order, "palette": self._orig_palette,
#    1614     })
# -> 1615 func(x=x, y=y, **kwargs)
#    1617 self._update_legend_data(ax)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:461, in _ScatterPlotter.plot(self, ax, kws)
#     458     kws["linewidth"] = linewidth
#     460 # Finalize the axes details
# --> 461 self._add_axis_labels(ax)
#     462 if self.legend:
#     463     attrs = {"hue": "color", "size": "s", "style": None}
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_base.py:1199, in VectorPlotter._add_axis_labels(self, ax, default_x, default_y)
#    1197     ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1198 if not ax.get_ylabel():
# -> 1199     y_visible = any(t.get_visible() for t in ax.get_yticklabels())
#    1200     ax.set_ylabel(self.variables.get("y", default_y), visible=y_visible)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:1503, in Axis.get_ticklabels(self, minor, which)
#    1501 if minor:
#    1502     return self.get_minorticklabels()
# -> 1503 return self.get_majorticklabels()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:1461, in Axis.get_majorticklabels(self)
#    1459 """Return this Axis' major tick labels, as a list of `~.text.Text`."""
#    1460 self._update_ticks()
# -> 1461 ticks = self.get_major_ticks()
#    1462 labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1463 labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:1666, in Axis.get_major_ticks(self, numticks)
#    1651 r"""
#    1652 Return the list of major `.Tick`\s.
#    1653
#    (...)
#    1663     Use `.set_tick_params` instead if possible.
#    1664 """
#    1665 if numticks is None:
# -> 1666     numticks = len(self.get_majorticklocs())
#    1668 while len(self.majorTicks) < numticks:
#    1669     # Update the new tick label properties from the old.
#    1670     tick = self._get_tick(major=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:1531, in Axis.get_majorticklocs(self)
#    1529 def get_majorticklocs(self):
#    1530     """Return this Axis' major tick locations in data coordinates."""
# -> 1531     return self.major.locator()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py:2171, in MaxNLocator.__call__(self)
#    2169 def __call__(self):
#    2170     vmin, vmax = self.axis.get_view_interval()
# -> 2171     return self.tick_values(vmin, vmax)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py:2179, in MaxNLocator.tick_values(self, vmin, vmax)
#    2176     vmin = -vmax
#    2177 vmin, vmax = mtransforms.nonsingular(
#    2178     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2179 locs = self._raw_ticks(vmin, vmax)
#    2181 prune = self._prune
#    2182 if prune == 'lower':
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\ticker.py:2109, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2107 if self._nbins == 'auto':
#    2108     if self.axis is not None:
# -> 2109         nbins = np.clip(self.axis.get_tick_space(),
#    2110                         max(1, self._min_n_ticks - 1), 9)
#    2111     else:
#    2112         nbins = 9
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:2803, in YAxis.get_tick_space(self)
#    2802 def get_tick_space(self):
# -> 2803     ends = mtransforms.Bbox.unit().transformed(
#    2804         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2805     length = ends.height * 72
#    2806     # Having a spacing of at least 2 just looks good.
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py:470, in BboxBase.transformed(self, transform)
#     467 pts = self.get_points()
#     468 ll, ul, lr = transform.transform(np.array(
#     469     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
# --> 470 return Bbox([ll, [lr[0], ul[1]]])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\transforms.py:777, in Bbox.__init__(self, points, **kwargs)
#     773 self._ignore = True
#     774 # it is helpful in some contexts to know if the bbox is a
#     775 # default or has been mutated; we store the orig points to
#     776 # support the mutated methods
# --> 777 self._points_orig = self._points.copy()
#
# KeyboardInterrupt:
