# %% [markdown]
# #### 1. Import Libraries : Import necessary Python libraries for data manipulation, visualization, and clustering

# %%
#pip install --upgrade pandas seaborn scikit-learn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### 2. Load Data : Load the dataset into a pandas DataFrame.
# #### 3. Data Dictionary : Load a data dictionary that describes the dataset

# %%
data = pd.read_csv('ML3 data.csv')
cd = pd.read_excel('Data_Description.xlsx')

# %%
data.head(2)
# Out:
#     SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  73557         8         2         1        69       NaN         4
# 1  73558         8         2         1        54       NaN         3
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...      ar16      ar17      ar18      ar19  \
# 0         4         1       NaN  ...  1.470207  4.864849  3.636711 -9.174492
# 1         3         1       NaN  ... -7.363791 -2.566326  0.776046 -2.951925
#
#        ar20      ar21      ar22      ar23      ar24      ar25
# 0 -9.353410  5.153847  1.294983 -1.015693 -8.671692  5.423061
# 1 -0.538597  3.770290  6.711471  3.521875 -1.765809 -5.383746
#
# [2 rows x 662 columns]

# %%
cd.head(2)
# Out:
#   Variable Name         Variable Description Data File Name  \
# 0          SEQN  Respondent sequence number.         DEMO_H
# 1      SDDSRVYR           Data release cycle         DEMO_H
#
#                       Data File Description  Begin Year  EndYear  \
# 0  Demographic Variables and Sample Weights        2013     2014
# 1  Demographic Variables and Sample Weights        2013     2014
#
#       Component  Use Constraints
# 0  Demographics              NaN
# 1  Demographics              NaN

# %% [markdown]
# #### 4. Initial Data Exploration : Check the shape of the DataFrame and the number of missing values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9813 entries, 0 to 9812
# Columns: 662 entries, SEQN to ar25
# dtypes: float64(641), int64(21)
# memory usage: 49.6 MB

# %%
data.shape
# Out:
# (9813, 662)

# %%
cd.shape
# Out:
# (636, 8)

# %%
data.isnull().sum().sum()
# Out:
# 3326124

# %%
cd['Component'].unique()
# Out:
# array(['Demographics', 'Dietary', 'Laboratory'], dtype=object)

# %% [markdown]
# #### 5. Data Cleaning : Fill missing values in dietary columns with zeros based on the assumption that they are question answers.

# %%
dieteryColumns = cd[cd['Component'] == 'Dietary']["Variable Name"]
for col in dieteryColumns :
    data[col].fillna(0, inplace = True)

# %% [markdown]
# #### 6. Demographic Data Cleaning : Fill missing values in demographic columns with zeros.

# %%
demographicsColumns = cd[cd['Component'] == 'Demographics']["Variable Name"]
for col in demographicsColumns :
    data[col].fillna(0, inplace = True)

# %% [markdown]
# #### 7. Laboratory Data Cleaning : Fill missing values in laboratory columns with zeros.

# %%
labColumns = cd[cd['Component'] == 'Laboratory']["Variable Name"]
for col in labColumns :
    data[col].fillna(0, inplace = True)

# %% [markdown]
# #### 8. Final Missing Value Handling : Fill any remaining missing values in the dataset with zeros.

# %%
data.fillna(0, inplace = True)

# %% [markdown]
# #### 9. Feature Selection : Select numerical features for clustering and drop non-essential columns.

# %%
cd[cd['Component'] != 'Dietary'][cd['Component'] != 'Demographics'][cd['Component'] != 'Laboratory']
# Out:
# Empty DataFrame
# Columns: [Variable Name, Variable Description, Data File Name, Data File Description, Begin Year, EndYear, Component, Use Constraints]
# Index: []

# %%
print(data.shape)
print(cd.shape)
# Out:
# (9813, 662)
# (636, 8)

# %%
main_features = pd.concat([dieteryColumns, demographicsColumns, labColumns], axis=0)
print(main_features)
# Out:
# 47       WTDRD1
# 48       WTDR2D
# 49     DR1DRSTZ
# 50     DR1EXMER
# 51        DRABF
#          ...
# 631    URDUURLC
# 632     URXPREG
# 633      URXUAS
# 634      LBDB12
# 635    LBDB12SI
# Name: Variable Name, Length: 636, dtype: object

# %%
data = data.drop_duplicates()
cd = cd.drop_duplicates()

# %%
data = data.loc[:, ~data.T.duplicated()]
cd = cd.loc[:, ~cd.T.duplicated()]

# %% [markdown]
# #### 10. Data Transformation : Scale the numerical features using MinMaxScaler

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %% [markdown]
# #### 11. Optimal Cluster Identification : Use silhouette scores and the elbow method to find the optimal number of clusters for KMeans

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
max_k_Check = 31
for k in range(1, max_k_Check):
    kmeans = KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,max_k_Check), wcss)
plt.xticks(range(1, max_k_Check))
plt.xlabel("no of clusters")
plt.ylabel("wcss")
plt.show()

# %%
k = 8 # Considered based on above plotted graph
kmeans = KMeans(n_clusters=k,init="k-means++")
data_pred = kmeans.fit_predict(data_scaled)

# %%
plt.scatter(data_scaled[:,0], data_scaled[:,1], c=data_pred)
plt.show()

# %%
from kneed import KneeLocator
kl = KneeLocator(range(1, max_k_Check), wcss, curve = "convex", direction = "decreasing")
elbow_k = kl.elbow
print(f"K value determined using elbow method is {elbow_k}")
# Out:
# K value determined using elbow method is 8

# %%
from sklearn.metrics import silhouette_score
silhouette_coefficients = []
for k in range(2, max_k_Check) :
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(data_scaled)
    score = silhouette_score(data_scaled, kmeans.labels_)
    silhouette_coefficients.append(score)
print(silhouette_coefficients)
# Out:
# [0.17017432649094302, 0.22707808861991988, 0.19509595416692452, 0.20389470650263, 0.1886542732902138, 0.18781290050025465, 0.18960372613865872, 0.19334989526182667, 0.16198674241559366, 0.17590241632126202, 0.16152449375211284, 0.16117251149228407, 0.16956645989734434, 0.15496043312956892, 0.14092662872600478, 0.15268158564531747, 0.14743019828737966, 0.15289717813520745, 0.13466096275213466, 0.14503370721902067, 0.1344142639188005, 0.13487002007975749, 0.12787942978108355, 0.1356510788589329, 0.12617559987826646, 0.1287552251425966, 0.13550608243547163, 0.1260125717820415, 0.1245664085706765]

# %%
plt.plot(range(2, max_k_Check), silhouette_coefficients)
plt.xticks(range(2, max_k_Check))
plt.xlabel("no of clusters")
plt.ylabel("silhouette_coefficients")
plt.show()

# %% [markdown]
# #### 12. KMeans Clustering : Perform KMeans clustering with the identified optimal number of clusters.

# %%
kmeans = KMeans(n_clusters=elbow_k, random_state=42)
cluster_labels = kmeans.fit_predict(data_scaled)
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = cluster_labels

# %% [markdown]
# #### 13. Correlation Analysis : Analyze the correlation of features with the cluster labels to identify highly correlated features.

# %%
data.shape
# Out:
# (9813, 648)

# %%
data_scaled.shape
# Out:
# (9813, 648)

# %%
corr_matrix = data.corr().abs()
corr_matrix_cols = corr_matrix.columns

# %%
for col in corr_matrix_cols :
    filtered_corr_matrix = corr_matrix[col][corr_matrix[col] > 0.89]
    if col in filtered_corr_matrix.index :
        filtered_corr_matrix.drop(col, inplace = True)
    if filtered_corr_matrix.shape[0] > 20 :
        print(f"\n----Corrleaton for the feature {col}")
        print(filtered_corr_matrix.index)
# Out:
# ----Corrleaton for the feature DRD370C
# Index(['DRD370A', 'DRD370B', 'DRD370D', 'DRD370E', 'DRD370F', 'DRD370G',
#        'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370E
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370F', 'DRD370G',
#        'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370F
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370G',
#        'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370G
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370H
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370I
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370J', 'DRD370K', 'DRD370L', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370J
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370K', 'DRD370L', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370K
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370L', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370L
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370M',
#        'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370N
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L',
#        'DRD370M', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370O
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L',
#        'DRD370M', 'DRD370N', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370P
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L',
#        'DRD370M', 'DRD370N', 'DRD370O', 'DRD370Q', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370Q
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L',
#        'DRD370M', 'DRD370N', 'DRD370O', 'DRD370P', 'DRD370R', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370R
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L',
#        'DRD370M', 'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370S',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370S
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L',
#        'DRD370M', 'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R',
#        'DRD370T', 'DRD370U', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370U
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L',
#        'DRD370M', 'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R',
#        'DRD370S', 'DRD370T', 'DRD370V'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD370V
# Index(['DRD370A', 'DRD370B', 'DRD370C', 'DRD370D', 'DRD370E', 'DRD370F',
#        'DRD370G', 'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L',
#        'DRD370M', 'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R',
#        'DRD370S', 'DRD370T', 'DRD370U'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXGH
# Index(['ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31', 'ORXH33',
#        'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH06
# Index(['ORXGH', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31', 'ORXH33',
#        'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH11
# Index(['ORXGH', 'ORXH06', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31', 'ORXH33',
#        'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH16
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH18', 'ORXH26', 'ORXH31', 'ORXH33',
#        'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH18
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH26', 'ORXH31', 'ORXH33',
#        'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH26
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH31', 'ORXH33',
#        'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH31
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH33',
#        'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH33
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH35
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH39
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH40
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH42
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH45', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH45
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH51', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH51
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH52',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH52
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH53
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH54
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH55
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH56
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH58', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH58
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH59', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH59
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH61',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH61
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH62
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH64
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH66
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH67
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH68', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH68
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH69', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH69
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH70',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH70
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH71
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH72
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH73
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH72', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH81
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH72', 'ORXH73', 'ORXH82', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH82
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH83', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH83
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH84',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXH84
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83',
#        'ORXHPC', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXHPC
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83',
#        'ORXH84', 'ORXHPI', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXHPI
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83',
#        'ORXH84', 'ORXHPC', 'ORXHPV'],
#       dtype='object')
#
# ----Corrleaton for the feature ORXHPV
# Index(['ORXGH', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51',
#        'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59',
#        'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69',
#        'ORXH70', 'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83',
#        'ORXH84', 'ORXHPC', 'ORXHPI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRPCR.x
# Index(['LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x', 'LBDR26.x', 'LBDR31.x',
#        'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x', 'LBDR45.x',
#        'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x', 'LBDR56.x',
#        'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x', 'LBDR66.x',
#        'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x', 'LBDR72.x',
#        'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x', 'LBDR89.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRHP.x
# Index(['LBDRLP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x', 'LBDR26.x',
#        'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR06.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x', 'LBDR26.x',
#        'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR11.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR16.x', 'LBDR18.x', 'LBDR26.x',
#        'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR16.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR18.x', 'LBDR26.x',
#        'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR18.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR26.x',
#        'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR26.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR31.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR33.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR35.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR39.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR40.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR40.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR42.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR42.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR45.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR51.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR52.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR53.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR54.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR54.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR55.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR55.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR56.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR58.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR59.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR61.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR62.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR62.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR64.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR64.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR66.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR67.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR68.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR69.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR70.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR70.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR71.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR71.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR72.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR71.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR73.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR71.x', 'LBDR72.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR81.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR71.x', 'LBDR72.x', 'LBDR73.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR82.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR71.x', 'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR83.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR71.x', 'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR84.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR71.x', 'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x',
#        'LBDR89.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR89.x
# Index(['LBDRPCR.x', 'LBDRHP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR71.x', 'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x',
#        'LBDR84.x', 'LBDRPI.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRPI.x
# Index(['LBDRHP.x', 'LBDRLP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x',
#        'LBDR26.x', 'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x',
#        'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x',
#        'LBDR64.x', 'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x',
#        'LBDR71.x', 'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x',
#        'LBDR84.x', 'LBDR89.x'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXHP2C
# Index(['LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRPCR.y
# Index(['LBXHP2C', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRHP.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
# ...
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR45.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR51.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR52.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR53.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR54.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR55.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR56.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR58.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR59.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR61.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR62.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR64.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR66.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR67.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR68.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR69.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR70.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR71.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR72.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR73.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR81.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR82.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR83.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR82.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR84.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR82.y', 'LBDR83.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR89.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR82.y', 'LBDR83.y', 'LBDR84.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRPI.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR82.y', 'LBDR83.y', 'LBDR84.y', 'LBDR89.y'],
#       dtype='object')

# %%
highly_corr_cols_to_delete = ['DRD370A', 'DRD370B', 'DRD370D', 'DRD370E', 'DRD370F', 'DRD370G',
       'DRD370H', 'DRD370I', 'DRD370J', 'DRD370K', 'DRD370L', 'DRD370M',
       'DRD370N', 'DRD370O', 'DRD370P', 'DRD370Q', 'DRD370R', 'DRD370S',
       'DRD370T', 'DRD370U', 'DRD370V', 'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31', 'ORXH33',
       'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45', 'ORXH51', 'ORXH52',
       'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56', 'ORXH58', 'ORXH59', 'ORXH61',
       'ORXH62', 'ORXH64', 'ORXH66', 'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70',
       'ORXH71', 'ORXH72', 'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84',
       'ORXHPC', 'ORXHPI', 'ORXHPV', 'LBDRLP.x', 'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x', 'LBDR26.x',
       'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x', 'LBDR42.x',
       'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x', 'LBDR54.x', 'LBDR55.x',
       'LBDR56.x', 'LBDR58.x', 'LBDR59.x', 'LBDR61.x', 'LBDR62.x', 'LBDR64.x',
       'LBDR66.x', 'LBDR67.x', 'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x',
       'LBDR72.x', 'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
       'LBDR89.x', 'LBDRPI.x']
data = data.drop(columns = highly_corr_cols_to_delete, axis =1)

# %%
corr_matrix = data.corr().abs()
corr_matrix_cols = corr_matrix.columns
for col in corr_matrix_cols :
    filtered_corr_matrix = corr_matrix[col][corr_matrix[col] > 0.89]
    if col in filtered_corr_matrix.index :
        filtered_corr_matrix.drop(col, inplace = True)
    if filtered_corr_matrix.shape[0] > 15 :
        print(f"\n----Corrleaton for the feature {col}")
        print(filtered_corr_matrix.index)
# Out:
# ----Corrleaton for the feature LBXSAL
# Index(['LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH', 'LBDSCHSI',
#        'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI', 'LBXSNASI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDSALSI
# Index(['LBXSAL', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH', 'LBDSCHSI',
#        'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI', 'LBXSNASI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSC3SI
# Index(['LBXSAL', 'LBDSALSI', 'LBXSCA', 'LBDSCASI', 'LBXSCH', 'LBDSCHSI',
#        'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI', 'LBXSNASI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSCA
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBDSCASI', 'LBXSCH', 'LBDSCHSI',
#        'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI', 'LBXSNASI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDSCASI
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBXSCH', 'LBDSCHSI',
#        'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI', 'LBXSNASI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSCLSI
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH',
#        'LBDSCHSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI', 'LBXSNASI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSGB
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH',
#        'LBDSCHSI', 'LBXSCLSI', 'LBDSGBSI', 'LBXSKSI', 'LBXSNASI', 'LBXSOSSI',
#        'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDSGBSI
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH',
#        'LBDSCHSI', 'LBXSCLSI', 'LBXSGB', 'LBXSKSI', 'LBXSNASI', 'LBXSOSSI',
#        'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSKSI
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH',
#        'LBDSCHSI', 'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSLDSI', 'LBXSNASI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSNASI
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH',
#        'LBDSCHSI', 'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSOSSI
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH',
#        'LBDSCHSI', 'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI',
#        'LBXSNASI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSTP
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH',
#        'LBDSCHSI', 'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI',
#        'LBXSNASI', 'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBDSTPSI', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDSTPSI
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH',
#        'LBDSCHSI', 'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI',
#        'LBXSNASI', 'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBXSUA',
#        'LBDSUASI', 'LBXGH'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXGH
# Index(['LBXSAL', 'LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCLSI',
#        'LBXSGB', 'LBDSGBSI', 'LBXSGL', 'LBDSGLSI', 'LBXSKSI', 'LBXSNASI',
#        'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXHP2C
# Index(['LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRPCR.y
# Index(['LBXHP2C', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRHP.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRLP.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR06.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR11.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR11.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR16.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR16.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR18.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR26.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR31.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR33.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR35.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR39.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR40.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR42.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR45.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR51.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR52.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR52.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR53.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR53.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR54.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR55.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR56.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR58.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR59.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR59.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR61.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR61.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR62.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR64.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR66.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR67.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR68.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR68.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR69.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR69.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR70.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR71.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR72.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR73.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR81.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR81.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR82.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR82.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR83.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR82.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR84.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR82.y', 'LBDR83.y', 'LBDR89.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDR89.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR82.y', 'LBDR83.y', 'LBDR84.y', 'LBDRPI.y'],
#       dtype='object')
#
# ----Corrleaton for the feature LBDRPI.y
# Index(['LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y',
#        'LBDR16.y', 'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y',
#        'LBDR39.y', 'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y',
#        'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y',
#        'LBDR69.y', 'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y',
#        'LBDR82.y', 'LBDR83.y', 'LBDR84.y', 'LBDR89.y'],
#       dtype='object')

# %%
highly_corr_cols_to_delete = ['LBDSALSI', 'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH', 'LBDSCHSI',
       'LBXSCLSI', 'LBXSGB', 'LBDSGBSI', 'LBXSKSI', 'LBXSLDSI', 'LBXSNASI',
       'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTP', 'LBDSTPSI', 'LBXSUA',
       'LBDSUASI', 'LBXGH', 'LBDRPCR.y', 'LBDRHP.y', 'LBDRLP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y',
       'LBDR18.y', 'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
       'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y', 'LBDR53.y',
       'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y', 'LBDR59.y', 'LBDR61.y',
       'LBDR62.y', 'LBDR64.y', 'LBDR66.y', 'LBDR67.y', 'LBDR68.y', 'LBDR69.y',
       'LBDR70.y', 'LBDR71.y', 'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y',
       'LBDR83.y', 'LBDR84.y', 'LBDR89.y', 'LBDRPI.y']
data = data.drop(columns = highly_corr_cols_to_delete, axis =1)

# %%
corr_matrix = data.corr().abs()
corr_matrix_cols = corr_matrix.columns
for col in corr_matrix_cols :
    filtered_corr_matrix = corr_matrix[col][corr_matrix[col] > 0.89]
    if col in filtered_corr_matrix.index :
        filtered_corr_matrix.drop(col, inplace = True)
    if filtered_corr_matrix.shape[0] > 5 :
        print(f"\n----Corrleaton for the feature {col}")
        print(filtered_corr_matrix.index)
# Out:
# ----Corrleaton for the feature DR1TTFAT
# Index(['DR1TKCAL', 'DR1TSFAT', 'DR1TMFAT', 'DR1TPFAT', 'DR1TS160', 'DR1TS180',
#        'DR1TM181'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350A
# Index(['DRD350B', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350F', 'DRD350G',
#        'DRD350H', 'DRD350I', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350B
# Index(['DRD350A', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350F', 'DRD350G',
#        'DRD350I', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350C
# Index(['DRD350A', 'DRD350B', 'DRD350D', 'DRD350E', 'DRD350F', 'DRD350G',
#        'DRD350H', 'DRD350I', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350D
# Index(['DRD350A', 'DRD350B', 'DRD350C', 'DRD350E', 'DRD350F', 'DRD350G',
#        'DRD350H', 'DRD350I', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350E
# Index(['DRD350A', 'DRD350B', 'DRD350C', 'DRD350D', 'DRD350F', 'DRD350G',
#        'DRD350H', 'DRD350I', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350F
# Index(['DRD350A', 'DRD350B', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350G',
#        'DRD350H', 'DRD350I', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350G
# Index(['DRD350A', 'DRD350B', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350F',
#        'DRD350H', 'DRD350I', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350H
# Index(['DRD350A', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350F', 'DRD350G',
#        'DRD350I', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350I
# Index(['DRD350A', 'DRD350B', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350F',
#        'DRD350G', 'DRD350H', 'DRD350J', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350J
# Index(['DRD350A', 'DRD350B', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350F',
#        'DRD350G', 'DRD350H', 'DRD350I', 'DRD350K'],
#       dtype='object')
#
# ----Corrleaton for the feature DRD350K
# Index(['DRD350A', 'DRD350B', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350F',
#        'DRD350G', 'DRD350H', 'DRD350I', 'DRD350J'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXRBCSI
# Index(['LBXHGB', 'LBXHCT', 'LBXMCVSI', 'LBXMCHSI', 'LBXMC', 'LBXRDW',
#        'LBXMPSI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXHGB
# Index(['LBXRBCSI', 'LBXHCT', 'LBXMCVSI', 'LBXMCHSI', 'LBXMC', 'LBXRDW',
#        'LBXMPSI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXHCT
# Index(['LBXRBCSI', 'LBXHGB', 'LBXMCVSI', 'LBXMCHSI', 'LBXMC', 'LBXRDW',
#        'LBXMPSI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXMCVSI
# Index(['LBXRBCSI', 'LBXHGB', 'LBXHCT', 'LBXMCHSI', 'LBXMC', 'LBXRDW',
#        'LBXMPSI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXMCHSI
# Index(['LBXRBCSI', 'LBXHGB', 'LBXHCT', 'LBXMCVSI', 'LBXMC', 'LBXRDW',
#        'LBXMPSI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXMC
# Index(['LBXRBCSI', 'LBXHGB', 'LBXHCT', 'LBXMCVSI', 'LBXMCHSI', 'LBXRDW',
#        'LBXMPSI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXRDW
# Index(['LBXRBCSI', 'LBXHGB', 'LBXHCT', 'LBXMCVSI', 'LBXMCHSI', 'LBXMC',
#        'LBXMPSI'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXMPSI
# Index(['LBXRBCSI', 'LBXHGB', 'LBXHCT', 'LBXMCVSI', 'LBXMCHSI', 'LBXMC',
#        'LBXRDW'],
#       dtype='object')
#
# ----Corrleaton for the feature LBXSSE
# Index(['LBXSCU', 'LBDSCUSI', 'LBDSSESI', 'LBXSZN', 'LBDSZNSI', 'URDUA5LC'], dtype='object')
#
# ----Corrleaton for the feature LBDSSESI
# Index(['LBXSCU', 'LBDSCUSI', 'LBXSSE', 'LBXSZN', 'LBDSZNSI', 'URDUA5LC'], dtype='object')
#
# ----Corrleaton for the feature LBXSZN
# Index(['LBXSCU', 'LBDSCUSI', 'LBXSSE', 'LBDSSESI', 'LBDSZNSI', 'URDUA5LC'], dtype='object')
#
# ----Corrleaton for the feature LBDSZNSI
# Index(['LBXSCU', 'LBDSCUSI', 'LBXSSE', 'LBDSSESI', 'LBXSZN', 'URDUA5LC'], dtype='object')

# %%
highly_corr_cols_to_delete = ['DR1TKCAL', 'DR1TSFAT', 'DR1TMFAT', 'DR1TPFAT', 'DR1TS160', 'DR1TS180',
       'DR1TM181', 'DRD350B', 'DRD350C', 'DRD350D', 'DRD350E', 'DRD350F', 'DRD350G',
       'DRD350H', 'DRD350I', 'DRD350J', 'DRD350K', 'LBXHGB', 'LBXHCT', 'LBXMCVSI', 'LBXMCHSI', 'LBXMC', 'LBXRDW',
       'LBXMPSI', 'LBXSCU', 'LBDSCUSI', 'LBDSSESI', 'LBXSZN', 'LBDSZNSI', 'URDUA5LC']
data = data.drop(columns = highly_corr_cols_to_delete, axis =1)

# %%
corr_matrix = data.corr().abs()
corr_matrix_cols = corr_matrix.columns
for col in corr_matrix_cols :
    filtered_corr_matrix = corr_matrix[col][corr_matrix[col] > 0.89]
    if col in filtered_corr_matrix.index :
        filtered_corr_matrix.drop(col, inplace = True)
    if filtered_corr_matrix.shape[0] > 3 :
        print(f"\n----Corrleaton for the feature {col}")
        print(filtered_corr_matrix.index)
# Out:
# ----Corrleaton for the feature PHQ020
# Index(['PHQ030', 'PHQ040', 'PHQ050', 'PHQ060'], dtype='object')
#
# ----Corrleaton for the feature PHQ030
# Index(['PHQ020', 'PHQ040', 'PHQ050', 'PHQ060'], dtype='object')
#
# ----Corrleaton for the feature PHQ040
# Index(['PHQ020', 'PHQ030', 'PHQ050', 'PHQ060'], dtype='object')
#
# ----Corrleaton for the feature PHQ050
# Index(['PHQ020', 'PHQ030', 'PHQ040', 'PHQ060'], dtype='object')
#
# ----Corrleaton for the feature PHQ060
# Index(['PHQ020', 'PHQ030', 'PHQ040', 'PHQ050'], dtype='object')
#
# ----Corrleaton for the feature LBXHBC
# Index(['LBDHBG', 'LBDHD', 'LBDHEG', 'LBDHEM', 'LBXTTG'], dtype='object')
#
# ----Corrleaton for the feature LBDHBG
# Index(['LBXHBC', 'LBDHD', 'LBDHEG', 'LBDHEM', 'LBXTTG'], dtype='object')
#
# ----Corrleaton for the feature LBDHD
# Index(['LBXHBC', 'LBDHBG', 'LBDHEG', 'LBDHEM', 'LBXTTG'], dtype='object')
#
# ----Corrleaton for the feature LBDHEG
# Index(['LBXHBC', 'LBDHBG', 'LBDHD', 'LBDHEM', 'LBXTTG'], dtype='object')
#
# ----Corrleaton for the feature LBDHEM
# Index(['LBXHBC', 'LBDHBG', 'LBDHD', 'LBDHEG', 'LBXTTG'], dtype='object')
#
# ----Corrleaton for the feature LBXTTG
# Index(['LBXHBC', 'LBDHBG', 'LBDHD', 'LBDHEG', 'LBDHEM'], dtype='object')

# %%
highly_corr_cols_to_delete = ['PHQ030', 'PHQ040', 'PHQ050', 'PHQ060', 'LBDHBG', 'LBDHD', 'LBDHEG', 'LBDHEM', 'LBXTTG']
data = data.drop(columns = highly_corr_cols_to_delete, axis =1)

# %%
corr_matrix = data.corr().abs()
corr_matrix_cols = corr_matrix.columns
for col in corr_matrix_cols :
    filtered_corr_matrix = corr_matrix[col][corr_matrix[col] > 0.89]
    if col in filtered_corr_matrix.index :
        filtered_corr_matrix.drop(col, inplace = True)
    if filtered_corr_matrix.shape[0] > 2 :
        print(f"\n----Corrleaton for the feature {col}")
        print(filtered_corr_matrix.index)
# Out:
# ----Corrleaton for the feature LBXAPB
# Index(['LBDAPBSI', 'LBDLDL', 'LBDLDLSI'], dtype='object')
#
# ----Corrleaton for the feature LBDAPBSI
# Index(['LBXAPB', 'LBDLDL', 'LBDLDLSI'], dtype='object')
#
# ----Corrleaton for the feature LBDLDL
# Index(['LBXAPB', 'LBDAPBSI', 'LBDLDLSI'], dtype='object')
#
# ----Corrleaton for the feature LBDLDLSI
# Index(['LBXAPB', 'LBDAPBSI', 'LBDLDL'], dtype='object')
#
# ----Corrleaton for the feature LBXBGE
# Index(['LBDBGELC', 'LBXBSE', 'LBDBSESI'], dtype='object')
#
# ----Corrleaton for the feature LBDBGELC
# Index(['LBXBGE', 'LBXBSE', 'LBDBSESI'], dtype='object')
#
# ----Corrleaton for the feature LBXGLT
# Index(['LBDGLTSI', 'GTDBL2MN', 'GTDDR2MN'], dtype='object')
#
# ----Corrleaton for the feature LBDGLTSI
# Index(['LBXGLT', 'GTDBL2MN', 'GTDDR2MN'], dtype='object')
#
# ----Corrleaton for the feature GTDBL2MN
# Index(['LBXGLT', 'LBDGLTSI', 'GTDDR2MN'], dtype='object')
#
# ----Corrleaton for the feature GTDDR2MN
# Index(['LBXGLT', 'LBDGLTSI', 'GTDBL2MN'], dtype='object')
#
# ----Corrleaton for the feature LBXBSE
# Index(['LBXBGE', 'LBDBGELC', 'LBDBSESI'], dtype='object')
#
# ----Corrleaton for the feature LBDBSESI
# Index(['LBXBGE', 'LBDBGELC', 'LBXBSE'], dtype='object')

# %%
highly_corr_cols_to_delete = ['LBDAPBSI', 'LBDLDL', 'LBDLDLSI', 'LBDGLTSI', 'GTDBL2MN', 'GTDDR2MN', 'LBXBGE', 'LBDBGELC', 'LBDBSESI']
data = data.drop(columns = highly_corr_cols_to_delete, axis =1)

# %%
corr_matrix = data.corr().abs()
corr_matrix_cols = corr_matrix.columns
for col in corr_matrix_cols :
    filtered_corr_matrix = corr_matrix[col][corr_matrix[col] > 0.89]
    if col in filtered_corr_matrix.index :
        filtered_corr_matrix.drop(col, inplace = True)
    if filtered_corr_matrix.shape[0] > 1 :
        print(f"\n----Corrleaton for the feature {col}")
        print(filtered_corr_matrix.index)
# Out:
# ----Corrleaton for the feature MIAPROXY
# Index(['MIALANG', 'MIAINTRP'], dtype='object')
#
# ----Corrleaton for the feature DR1TPROT
# Index(['DR1TPHOS', 'DR1TSELE'], dtype='object')
#
# ----Corrleaton for the feature DR1TCHOL
# Index(['DR1TCHL', 'DR1TP204'], dtype='object')
#
# ----Corrleaton for the feature DR1TFDFE
# Index(['DR1TFOLA', 'DR1TFA'], dtype='object')
#
# ----Corrleaton for the feature DR1TS040
# Index(['DR1TS060', 'DR1TS140'], dtype='object')
#
# ----Corrleaton for the feature DR1TS060
# Index(['DR1TS040', 'DR1TS140'], dtype='object')
#
# ----Corrleaton for the feature DR1TS140
# Index(['DR1TS040', 'DR1TS060'], dtype='object')
#
# ----Corrleaton for the feature LBXBGM
# Index(['LBXTHG', 'LBDTHGSI'], dtype='object')
#
# ----Corrleaton for the feature LBXPFBS
# Index(['LBDPFBSL', 'LBDPFHPL'], dtype='object')
#
# ----Corrleaton for the feature LBDPFBSL
# Index(['LBXPFBS', 'LBDPFHPL'], dtype='object')
#
# ----Corrleaton for the feature LBDPFHPL
# Index(['LBXPFBS', 'LBDPFBSL'], dtype='object')
#
# ----Corrleaton for the feature URXECP
# Index(['URXMHH', 'URXMOH'], dtype='object')
#
# ----Corrleaton for the feature URXMHH
# Index(['URXECP', 'URXMOH'], dtype='object')
#
# ----Corrleaton for the feature URXMOH
# Index(['URXECP', 'URXMHH'], dtype='object')
#
# ----Corrleaton for the feature LBXTHG
# Index(['LBXBGM', 'LBDTHGSI'], dtype='object')
#
# ----Corrleaton for the feature LBDTHGSI
# Index(['LBXBGM', 'LBXTHG'], dtype='object')

# %%
highly_corr_cols_to_delete = ['MIALANG', 'MIAINTRP', 'DR1TPHOS', 'DR1TSELE', 'DR1TCHL', 'DR1TP204', 'DR1TCHL', 'DR1TP204', 
                             'DR1TFOLA', 'DR1TFA', 'DR1TS060', 'DR1TS140', 'LBXTHG', 'LBDTHGSI', 'LBDPFBSL', 'LBDPFHPL',
                             'URXMHH', 'URXMOH', 'LBXBGM', 'LBDTHGSI']
data = data.drop(columns = highly_corr_cols_to_delete, axis =1)

# %%
corr_matrix = data.corr().abs()
corr_matrix_cols = corr_matrix.columns
for col in corr_matrix_cols :
    filtered_corr_matrix = corr_matrix[col][corr_matrix[col] > 0.89]
    if col in filtered_corr_matrix.index :
        filtered_corr_matrix.drop(col, inplace = True)
    if filtered_corr_matrix.shape[0] > 2 :
        print(f"\n----Corrleaton for the feature {col}")
        print(filtered_corr_matrix.index)

# %%
print("The data sets's shape after dropping the highly correlated columns: ", data.shape)
# Out:
# The data sets's shape after dropping the highly correlated columns:  (9813, 393)

# %% [markdown]
# #### 14. Principal Component Analysis (PCA) : Perform PCA to reduce dimensionality while retaining 95% of the variance.

# %%
from sklearn.decomposition import PCA

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(data)

# %%
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_scaled)
print(f"Original features: {X_scaled.shape[1]}")
print(f"Reduced features after PCA: {X_pca.shape[1]}")
# Out:
# Original features: 426
# Reduced features after PCA: 106

# %% [markdown]
# #### 15. KMeans with PCA : Apply KMeans clustering on the principal components and visualize the clusters in a scatter plot.

# %%
silhouette_scores = []
inertias = []
K = range(2, 11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_pca)
    inertias.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X_pca, kmeans.labels_))
kl = KneeLocator(K, inertias, curve="convex", direction="decreasing")
elbow_k = kl.elbow
print(f"Elbow method optimal k: {kl.elbow}")
print(f"Silhouette optimal k: {K[silhouette_scores.index(max(silhouette_scores))]}")
# Out:
# Elbow method optimal k: 5
# Silhouette optimal k: 3

# %%
kmeans = KMeans(n_clusters=elbow_k, random_state=42)
cluster_labels = kmeans.fit_predict(X_pca)
pca_df = pd.DataFrame(X_pca[:, :2], columns=['PC1', 'PC2'])
pca_df['Cluster'] = cluster_labels
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='Cluster', palette='Set2', s=60)
plt.title('KMeans Clusters (PCA-reduced Data)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 16. DBSCAN Clustering : Attempt DBSCAN clustering on the principal components and evaluate the results.

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, adjusted_rand_score
epss = [3.7,3.6,3.5,3.4,3.3,3.2,3.1,3.0,2.9,2.8,2.7]
for ep in epss:
    print(f'----- {ep}')
    X_for_dbscan = X_pca
    dbscan = DBSCAN(eps=ep, min_samples=5)
    dbscan_labels = dbscan.fit_predict(X_for_dbscan)
    n_clusters = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
    n_noise = list(dbscan_labels).count(-1)
    print(f"Estimated number of clusters: {n_clusters}")
    print(f"Estimated number of noise points: {n_noise}")
    if n_clusters > 1:
        sil_score = silhouette_score(X_for_dbscan, dbscan_labels)
        print(f"Silhouette Score: {sil_score:.4f}")
    else:
        print("Silhouette Score: Not applicable (less than 2 clusters)")
# Out:
# ----- 3.7
# Estimated number of clusters: 1
# Estimated number of noise points: 15
# Silhouette Score: Not applicable (less than 2 clusters)
# ----- 3.6
# Estimated number of clusters: 1
# Estimated number of noise points: 37
# Silhouette Score: Not applicable (less than 2 clusters)
# ----- 3.5
# Estimated number of clusters: 1
# Estimated number of noise points: 79
# Silhouette Score: Not applicable (less than 2 clusters)
# ----- 3.4
# Estimated number of clusters: 1
# Estimated number of noise points: 167
# Silhouette Score: Not applicable (less than 2 clusters)
# ----- 3.3
# Estimated number of clusters: 1
# Estimated number of noise points: 339
# Silhouette Score: Not applicable (less than 2 clusters)
# ----- 3.2
# Estimated number of clusters: 2
# Estimated number of noise points: 631
# Silhouette Score: 0.0768
# ----- 3.1
# Estimated number of clusters: 1
# Estimated number of noise points: 1002
# Silhouette Score: Not applicable (less than 2 clusters)
# ----- 3.0
# Estimated number of clusters: 3
# Estimated number of noise points: 1481
# Silhouette Score: 0.0367
# ----- 2.9
# Estimated number of clusters: 4
# Estimated number of noise points: 2045
# Silhouette Score: -0.0109
# ----- 2.8
# Estimated number of clusters: 10
# Estimated number of noise points: 2670
# Silhouette Score: -0.0690
# ----- 2.7
# Estimated number of clusters: 12
# Estimated number of noise points: 3301
# Silhouette Score: -0.0794

# %%
from sklearn.neighbors import NearestNeighbors

# %%
neigh = NearestNeighbors(n_neighbors=5)
nbrs = neigh.fit(X_pca)
distances, indices = nbrs.kneighbors(X_pca)
distances = np.sort(distances[:, 4])
plt.figure(figsize=(10, 5))
plt.plot(distances)
plt.title("k-distance Graph for DBSCAN (k=5)")
plt.xlabel("Points sorted by distance")
plt.ylabel("5th Nearest Neighbor Distance")
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, adjusted_rand_score

X_for_dbscan = X_pca
dbscan = DBSCAN(eps=3.2, min_samples=5)
dbscan_labels = dbscan.fit_predict(X_for_dbscan)
n_clusters = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
n_noise = list(dbscan_labels).count(-1)

print(f"Estimated number of clusters: {n_clusters}")
print(f"Estimated number of noise points: {n_noise}")

# Step 3: Evaluate clustering quality
if n_clusters > 1:
    sil_score = silhouette_score(X_for_dbscan, dbscan_labels)
    print(f"Silhouette Score: {sil_score:.4f}")
else:
    print("Silhouette Score: Not applicable (less than 2 clusters)")
# Out:
# Estimated number of clusters: 2
# Estimated number of noise points: 631
# Silhouette Score: 0.0768

# %% [markdown]
# #### 17. Conclusion : Conclude the analysis by summarizing the steps taken and the findings from the clustering analysis.

# %%
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans_labels = kmeans.fit_predict(X_pca)
score = silhouette_score(X_pca, kmeans_labels)
print(f"KMeans Silhouette Score: {score:.4f}")
# Out:
# KMeans Silhouette Score: 0.0991

# %% [markdown]
# Interpretation:
# A silhouette score of 0.0991 is still quite low, meaning:
# The clusters are not well separated,
# Data points are not clearly closer to their own cluster vs others,
# The structure in the data may not be naturally clusterable (at least linearly).

# %% [markdown]
# Both KMeans and DBSCAN are struggling to find strong, well-separated clusters.
# This can happen if:
# The features (even after PCA) don't contain meaningful group structure, or
# The clusters are not globular (KMeans assumes spherical clusters),
# The distance-based approach (like Euclidean) is not suited to your data.

# %%
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(n_clusters=n_clusters)
agg_labels = agg.fit_predict(X_pca)

from sklearn.metrics import silhouette_score
score = silhouette_score(X_pca, agg_labels)
print(f"Agglomerative Clustering Silhouette Score: {score:.4f}")
# Out:
# Agglomerative Clustering Silhouette Score: 0.0946

# %% [markdown]
# DBSCAN (eps=3.2) with 3	clusters score is 0.0768
# KMeans with 5 clusters score is 0.0991
# Agglomerative with 3 clusters score is 0.0946
#
# Determines:
# KMeans has the best (yet modest) score, meaning it creates slightly more distinct clusters compared to the others.
# All scores are < 0.2, which generally means:
# There’s weak natural clustering in your dataset.
# It may still be useful for exploratory segmentation, but not reliable for production or strong inferences.

# %%
#!pip install umap-learn

# %%
import umap.umap_ as umap

# %%
reducer = umap.UMAP(n_components=2, random_state=42)
X_umap = reducer.fit_transform(X_scaled)
kmeans = KMeans(n_clusters=3, random_state=42)
labels = kmeans.fit_predict(X_umap)
score = silhouette_score(X_umap, labels)
print(f"UMAP + KMeans Silhouette Score: {score:.4f}")
# Out:
# UMAP + KMeans Silhouette Score: 0.4182

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_umap[:,0], X_umap[:,1], c=labels, cmap='viridis', s=10)
plt.title('UMAP + KMeans Clustering (3 clusters)')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.colorbar(label='Cluster')
plt.show()
